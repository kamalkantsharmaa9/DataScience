# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('mnist\mnist_test.csv')
x=df.values
split=int(0.8*x.shape[0])
x_train=x[0:split,1:]
y_train=x[0:split,0]
x_test=x[split:,1:]
y_test=x[split:,0]
def imgview(mat):
    plt.imshow(mat.reshape(28,28),cmap='gray')
    plt.show()
def dist(x1,x2):
    return np.sqrt(sum((x1-x2)**2))
def knn(X,Y,querypoints,k=5):
    vars=[]
    m=X.shape[0]
    for i in range (m):
        d=dist(querypoints,X[i])
        vars.append([d,Y[i]])
    vars=sorted(vars)
    vars=vars[:k]
    vars=np.array(vars)
    newval=np.unique(vars[:,1],return_counts=True)
    index=newval[1].argmax()
    pred=newval[0][index]
    return pred

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dfx=pd.read_csv('training\Diabetes_XTrain.csv')
dfy=pd.read_csv('training\Diabetes_YTrain.csv')
dftest=pd.read_csv('training\Diabetes_Xtest.csv')
x_test=dftest.values
x_train=dfx.values
y_train=dfy.values
num=x_train.shape[0]
def dist(x1,x2):
    return np.sqrt(sum((x1-x2)**2))
def knn(X,Y,querypoints,k=10):
    vars=[]
    m=X.shape[0]
    for i in range (m):
        d=dist(querypoints,X[i])
        vars.append([d,Y[i]])
    vars=sorted(vars)
    vars=vars[:k]
    vars=np.array(vars)
    newval=np.unique(vars[:,1],return_counts=True)
    index=newval[1].argmax()
    pred=newval[0][index]
    return pred


with open('myfile2.csv','r+',encoding='UTF-8') as file:
    file.write('Outcome\n')
    size=x_test.shape[0]
    for i in range(size):
        val=int(knn(x_train,y_train,x_test[i]))
        file.write(str(val))
        file.write('\n')
# Out:
# C:\Users\kip31\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import cv2

img = cv2.imread("pic\logo.jpg")
gray = cv2.imread('pic\logo.jpg',cv2.IMREAD_GRAYSCALE)


cv2.imshow('image',img)
cv2.imshow('gray',gray)
#Wait for any key before image disappears
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
#newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
"""plt.show()
plt.imshow(newimg)
plt.show()"""
# Out:
# 'plt.show()\nplt.imshow(newimg)\nplt.show()'

# %%
import cv2
cap=cv2.VideoCapture(0)
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
while True:
    ret,frame=cap.read()
    gray_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    if ret == False:
        continue
    faces=face_cascade.detectMultiScale(gray_frame,1.3,5)
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.imshow("videoframe",frame)
    key_pressed=cv2.waitKey(1)& 0xFF
    if key_pressed == ord('q'):
        break
cap.release()
cv2.destroyAlWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a7e27497f5b8> in <module>
#       7     if ret == False:
#       8         continue
# ----> 9     faces=face_cascade.detectMultiScale(gray_frame,1.3,5)
#      10     for(x,y,w,h) in faces:
#      11         cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np

cap=cv2.VideoCapture(0)
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
skip=0
file_name=input("tell the name of person in camera")
face_data=[]
dataset_path='./pic/'
while True:
    
    ret,frame=cap.read()
    
    if ret==False:
        continue
    faces=face_cascade.detectMultiScale(frame,1.3,5)
    faces=sorted(faces,key=lambda f:f[2]*f[3])
    for face in faces[-1:]:
        x,y,w,h=face
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,255,0),2)

        offset=10
        face_section=frame[y-offset:y+h+offset,x-offset:x+w+offset]
        face_section=cv2.resize(face_section,(100,100))
        if skip%10==0:
            face_data.append(face_section)
    cv2.imshow("videoframe",frame)
    cv2.imshow("facesection",face_section)
    skip+=1
    key_pressed=cv2.waitKey(1) & 0xff    
    if key_pressed==ord('q'):
        break
face_data=np.asarray(face_data)
face_data=face_data.reshape((face_data.shape[0],-1))
print(face_data.shape)
np.save(dataset_path+file_name+'.npy',face_data)
cap.release()
cv2.destroyALlWindows()
# Out:
# tell the name of person in cameranmnkmnk
# (92, 30000)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b8ec03a39b34> in <module>
#      38 np.save(dataset_path+file_name+'.npy',face_data)
#      39 cap.release()
# ---> 40 cv2.destroyALlWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destroyALlWindows'

# %%
q
